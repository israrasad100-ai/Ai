# %%
import pandas as pd

# %%
Data= pd.read_csv("data_for_ml.csv")

# %%
Data
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage  Gender Study_Method  \
# 0             2.0          6.0             3.0    Male   Self Study
# 1             3.0          7.0             2.0  Female     Coaching
# 2             4.0          6.0             4.0    male   Self study
# 3             5.0          8.0             3.0   Femle  Group Study
# 4             6.0          7.0             5.0    Male   Self Study
# 5             7.0          6.0             6.0  Female     coaching
# 6             8.0          7.0             4.0    Male  Group study
# 7             2.0          5.0             7.0  Female   Self Study
# 8             3.0          6.0             6.0    Male   Self Study
# 9             4.0          7.0             5.0  Female  Group Study
# 10            5.0          8.0             4.0    Male   Self Study
# 11            6.0          6.0             5.0  Female     Coaching
# 12            7.0          7.0             6.0    Male   Self study
# ...

# %%
Data.shape
# Out:
# (57, 7)

# %%
Data.dtypes
# Out:
# Hours_Studied     float64
# Sleep_Hours       float64
# Internet_Usage    float64
# Gender             object
# Study_Method       object
# Attendance        float64
# Final_Score       float64
# dtype: object

# %%
Data.duplicated().sum()
# Out:
# np.int64(25)

# %%
Data.drop_duplicates()
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage  Gender Study_Method  \
# 0             2.0          6.0             3.0    Male   Self Study
# 1             3.0          7.0             2.0  Female     Coaching
# 2             4.0          6.0             4.0    male   Self study
# 3             5.0          8.0             3.0   Femle  Group Study
# 4             6.0          7.0             5.0    Male   Self Study
# 5             7.0          6.0             6.0  Female     coaching
# 6             8.0          7.0             4.0    Male  Group study
# 7             2.0          5.0             7.0  Female   Self Study
# 8             3.0          6.0             6.0    Male   Self Study
# 9             4.0          7.0             5.0  Female  Group Study
# 10            5.0          8.0             4.0    Male   Self Study
# 11            6.0          6.0             5.0  Female     Coaching
# 12            7.0          7.0             6.0    Male   Self study
# ...

# %%
Data.drop_duplicates(inplace=True)

# %%
Data.duplicated().sum()
# Out:
# np.int64(0)

# %%
Data
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage  Gender Study_Method  \
# 0             2.0          6.0             3.0    Male   Self Study
# 1             3.0          7.0             2.0  Female     Coaching
# 2             4.0          6.0             4.0    male   Self study
# 3             5.0          8.0             3.0   Femle  Group Study
# 4             6.0          7.0             5.0    Male   Self Study
# 5             7.0          6.0             6.0  Female     coaching
# 6             8.0          7.0             4.0    Male  Group study
# 7             2.0          5.0             7.0  Female   Self Study
# 8             3.0          6.0             6.0    Male   Self Study
# 9             4.0          7.0             5.0  Female  Group Study
# 10            5.0          8.0             4.0    Male   Self Study
# 11            6.0          6.0             5.0  Female     Coaching
# 12            7.0          7.0             6.0    Male   Self study
# ...

# %%
Data.describe()
# Out:
#        Hours_Studied  Sleep_Hours  Internet_Usage  Attendance  Final_Score
# count      31.000000    31.000000       31.000000   31.000000    31.000000
# mean        5.548387     6.709677        4.580645   84.774194    69.903226
# std         2.618380     1.131181        1.962553    9.762888    13.526159
# min         1.000000     4.000000        1.000000   60.000000    40.000000
# 25%         3.500000     6.000000        3.000000   79.000000    61.000000
# 50%         6.000000     7.000000        5.000000   88.000000    72.000000
# 75%         7.500000     7.500000        6.000000   91.000000    78.000000
# max        10.000000     9.000000        9.000000   99.000000    94.000000

# %%
Data.isna().sum()
# Out:
# Hours_Studied     1
# Sleep_Hours       1
# Internet_Usage    1
# Gender            1
# Study_Method      1
# Attendance        1
# Final_Score       1
# dtype: int64

# %%
Data[Data['Hours_Studied'].isnull()]
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage Gender Study_Method  \
# 14            NaN          7.0             4.0   Male   Self Study
#
#     Attendance  Final_Score
# 14        80.0         65.0

# %%
Data[Data['Sleep_Hours'].isnull()]
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage  Gender Study_Method  \
# 15            5.0          NaN             5.0  Female     Coaching
#
#     Attendance  Final_Score
# 15        85.0         70.0

# %%
Data[Data['Internet_Usage'].isna()]
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage Gender Study_Method  \
# 16            6.0          6.0             NaN   Male  Group Study
#
#     Attendance  Final_Score
# 16        88.0         72.0

# %%
Data[Data['Gender'].isna()]
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage Gender Study_Method  \
# 17            7.0          7.0             6.0    NaN   Self Study
#
#     Attendance  Final_Score
# 17        90.0         75.0

# %%
Data[Data['Study_Method'].isna()]
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage  Gender Study_Method  \
# 18            8.0          8.0             3.0  Female          NaN
#
#     Attendance  Final_Score
# 18        92.0         80.0

# %%
Data[Data['Attendance'].isna()]
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage Gender Study_Method  \
# 19            4.0          6.0             5.0   Male   Self Study
#
#     Attendance  Final_Score
# 19         NaN         60.0

# %%
Data[Data['Final_Score'].isna()]
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage  Gender Study_Method  \
# 20            3.0          5.0             6.0  Female     Coaching
#
#     Attendance  Final_Score
# 20        78.0          NaN

# %%
Data['Hours_Studied'] = Data['Hours_Studied'].fillna(Data['Hours_Studied'].mean())

Data['Sleep_Hours'] = Data['Sleep_Hours'].fillna(Data['Sleep_Hours'].mean())

Data['Internet_Usage'] = Data['Internet_Usage'].fillna(Data['Internet_Usage'].mean())

Data['Attendance'] = Data['Attendance'].fillna(Data['Attendance'].mean())

Data['Final_Score'] = Data['Final_Score'].fillna(Data['Final_Score'].mean())

# %%
Data.isna().sum()
# Out:
# Hours_Studied     0
# Sleep_Hours       0
# Internet_Usage    0
# Gender            1
# Study_Method      1
# Attendance        0
# Final_Score       0
# dtype: int64

# %%
Data['Gender'] = Data['Gender'].fillna('Male')

# %%
Data['Study_Method'] = Data['Study_Method'].fillna('Groupe Studies')

# %%
Data.isna().sum()
# Out:
# Hours_Studied     0
# Sleep_Hours       0
# Internet_Usage    0
# Gender            0
# Study_Method      0
# Attendance        0
# Final_Score       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le_gender = LabelEncoder()
le_method = LabelEncoder()

Data['Gender'] = le_gender.fit_transform(Data['Gender'])
Data['Study_Method'] = le_method.fit_transform(Data['Study_Method'])

# %%
X = Data[['Hours_Studied']]

# %%
X
# Out:
#     Hours_Studied
# 0        2.000000
# 1        3.000000
# 2        4.000000
# 3        5.000000
# 4        6.000000
# 5        7.000000
# 6        8.000000
# 7        2.000000
# 8        3.000000
# 9        4.000000
# 10       5.000000
# 11       6.000000
# 12       7.000000
# 13       8.000000
# 14       5.548387
# 15       5.000000
# 16       6.000000
# 17       7.000000
# 18       8.000000
# 19       4.000000
# 20       3.000000
# 21       2.000000
# 22       5.000000
# 24       7.000000
# 25       8.000000
# 31       7.000000
# 47       1.000000
# 48       9.000000
# 49      10.000000
# 50       1.000000
# 51       9.000000
# 52      10.000000

# %%
y = Data['Final_Score']

# %%
y
# Out:
# 0     55.000000
# 1     60.000000
# 2     62.000000
# 3     70.000000
# 4     72.000000
# 5     75.000000
# 6     80.000000
# 7     50.000000
# 8     55.000000
# 9     65.000000
# 10    68.000000
# 11    72.000000
# 12    76.000000
# 13    85.000000
# 14    65.000000
# 15    70.000000
# 16    72.000000
# 17    75.000000
# 18    80.000000
# 19    60.000000
# 20    69.903226
# 21    52.000000
# 22    68.000000
# 24    75.000000
# 25    80.000000
# 31    76.000000
# 47    45.000000
# 48    88.000000
# 49    92.000000
# 50    40.000000
# 51    90.000000
# 52    94.000000
# Name: Final_Score, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#     Hours_Studied
# 4        6.000000
# 16       6.000000
# 5        7.000000
# 13       8.000000
# 11       6.000000
# 24       7.000000
# 1        3.000000
# 2        4.000000
# 47       1.000000
# 3        5.000000
# 21       2.000000
# 48       9.000000
# 22       5.000000
# 18       8.000000
# 52      10.000000
# 20       3.000000
# 7        2.000000
# 10       5.000000
# 14       5.548387
# 49      10.000000
# 19       4.000000
# 6        8.000000

# %%
y_test
# Out:
# 50    40.0
# 15    70.0
# 25    80.0
# 17    75.0
# 8     55.0
# 9     65.0
# 51    90.0
# 31    76.0
# 12    76.0
# 0     55.0
# Name: Final_Score, dtype: float64

# %%
y_train
# Out:
# 4     72.000000
# 16    72.000000
# 5     75.000000
# 13    85.000000
# 11    72.000000
# 24    75.000000
# 1     60.000000
# 2     62.000000
# 47    45.000000
# 3     70.000000
# 21    52.000000
# 48    88.000000
# 22    68.000000
# 18    80.000000
# 52    94.000000
# 20    69.903226
# 7     50.000000
# 10    68.000000
# 14    65.000000
# 49    92.000000
# 19    60.000000
# 6     80.000000
# Name: Final_Score, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
plt.scatter(Data["Hours_Studied"], Data["Final_Score"])

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from  sklearn.linear_model import LinearRegression

# %%
EDA= LinearRegression()

# %%
EDA.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
# array([[-1.85656665],
#        [-0.26338835],
#        [ 0.93149538],
#        [ 0.5332008 ],
#        [-1.0599775 ],
#        [-0.66168292],
#        [ 1.32978995],
#        [ 0.5332008 ],
#        [ 0.5332008 ],
#        [-1.45827207]])

# %%
EDA.coef_
# Out:
# array([12.1768836])

# %%
EDA.intercept_
# Out:
# np.float64(70.67741935483872)

# %%
y_pred = EDA.predict(X_test)

# %%
y_pred
# Out:
# array([48.07022337, 67.4701701 , 82.02013014, 77.17014346, 57.77019674,
#        62.62018342, 86.87011682, 77.17014346, 77.17014346, 52.92021005])

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9430208927999015

# %%
import joblib

# %%
joblib.dump(EDA, "Model1")
# Out:
# ['Model1']

# %% [markdown]
# ### MODEl 02

# %%
X = Data[['Hours_Studied','Sleep_Hours']]

# %%
X
# Out:
#     Hours_Studied  Sleep_Hours
# 0        2.000000     6.000000
# 1        3.000000     7.000000
# 2        4.000000     6.000000
# 3        5.000000     8.000000
# 4        6.000000     7.000000
# 5        7.000000     6.000000
# 6        8.000000     7.000000
# 7        2.000000     5.000000
# 8        3.000000     6.000000
# 9        4.000000     7.000000
# 10       5.000000     8.000000
# 11       6.000000     6.000000
# 12       7.000000     7.000000
# 13       8.000000     8.000000
# 14       5.548387     7.000000
# 15       5.000000     6.709677
# 16       6.000000     6.000000
# 17       7.000000     7.000000
# 18       8.000000     8.000000
# 19       4.000000     6.000000
# 20       3.000000     5.000000
# 21       2.000000     6.000000
# 22       5.000000     8.000000
# 24       7.000000     6.000000
# 25       8.000000     7.000000
# 31       7.000000     7.000000
# 47       1.000000     5.000000
# 48       9.000000     8.000000
# 49      10.000000     7.000000
# ...

# %%
y = Data[['Final_Score']]

# %%
y
# Out:
#     Final_Score
# 0     55.000000
# 1     60.000000
# 2     62.000000
# 3     70.000000
# 4     72.000000
# 5     75.000000
# 6     80.000000
# 7     50.000000
# 8     55.000000
# 9     65.000000
# 10    68.000000
# 11    72.000000
# 12    76.000000
# 13    85.000000
# 14    65.000000
# 15    70.000000
# 16    72.000000
# 17    75.000000
# 18    80.000000
# 19    60.000000
# 20    69.903226
# 21    52.000000
# 22    68.000000
# 24    75.000000
# 25    80.000000
# 31    76.000000
# 47    45.000000
# 48    88.000000
# 49    92.000000
# 50    40.000000
# 51    90.000000
# 52    94.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
plt.scatter(Data["Hours_Studied"],Data["Sleep_Hours"] ,Data["Final_Score"])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#     Hours_Studied  Sleep_Hours
# 4        6.000000          7.0
# 16       6.000000          6.0
# 5        7.000000          6.0
# 13       8.000000          8.0
# 11       6.000000          6.0
# 24       7.000000          6.0
# 1        3.000000          7.0
# 2        4.000000          6.0
# 47       1.000000          5.0
# 3        5.000000          8.0
# 21       2.000000          6.0
# 48       9.000000          8.0
# 22       5.000000          8.0
# 18       8.000000          8.0
# 52      10.000000          8.0
# 20       3.000000          5.0
# 7        2.000000          5.0
# 10       5.000000          8.0
# 14       5.548387          7.0
# 49      10.000000          7.0
# 19       4.000000          6.0
# 6        8.000000          7.0

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from  sklearn.linear_model import LinearRegression

# %%
EDA= LinearRegression()

# %%
EDA.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
# array([[-1.85656665, -2.59160528],
#        [-0.26338835, -0.01672003],
#        [ 0.93149538,  0.25916053],
#        [ 0.5332008 ,  0.25916053],
#        [-1.0599775 , -0.69109474],
#        [-0.66168292,  0.25916053],
#        [ 1.32978995,  2.15967106],
#        [ 0.5332008 ,  0.25916053],
#        [ 0.5332008 ,  0.25916053],
#        [-1.45827207, -0.69109474]])

# %%
EDA.coef_
# Out:
# array([[11.96834629,  0.3370145 ]])

# %%
EDA.intercept_
# Out:
# array([70.67741935])

# %%
y_pred = EDA.predict(X_test)

# %%
y_pred
# Out:
# array([[47.58397822],
#        [67.5194615 ],
#        [81.91321946],
#        [77.14629206],
#        [57.75833264],
#        [62.84550985],
#        [87.32064648],
#        [77.14629206],
#        [77.14629206],
#        [52.99140523]])

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9494594962505541

# %%
import joblib

# %%
joblib.dump(EDA, "Model12")
# Out:
# ['Model12']

# %% [markdown]
# ### INPPUT MODEl1

# %%
import joblib

# %%
Model1= joblib.load("Model1")

# %%
Model1.predict([[2]])
# Out:
# array([95.03118656])

# %%
def predict_Hours_Studied():
    hours = float(input("Enter Hours Studied: "))
    
    prediction = Model1.predict([[hours]])
    
    print("Predicted Final Score:", prediction[0])

# %%
 predict_Hours_Studied()
# Out:
# Enter Hours Studied:  2
# Predicted Final Score: 95.0311865576711

# %%
print(Model1.coef_)
# Out:
# [12.1768836]

# %%
print(Model1.intercept_)
# Out:
# 70.67741935483872

# %%
import joblib

# %%
Model12= joblib.load("Model12")

# %%
Model12.predict([[2,1]])
# Out:
# array([[94.95112645]])

# %%
def predict_score():
    hours = float(input("Enter Hours Studied: "))
    sleep = float(input("Enter Sleep Hours: "))
    
    prediction = Model12.predict([[hours, sleep]])
    
    return prediction[0]

# %%
predict_score()
# Out:
# Enter Hours Studied:  2
# Enter Sleep Hours:  1
# array([94.95112645])

# %% [markdown]
# ### 03 Model

# %%
X = Data[['Hours_Studied','Internet_Usage']]

# %%
X
# Out:
#     Hours_Studied  Internet_Usage
# 0        2.000000        3.000000
# 1        3.000000        2.000000
# 2        4.000000        4.000000
# 3        5.000000        3.000000
# 4        6.000000        5.000000
# 5        7.000000        6.000000
# 6        8.000000        4.000000
# 7        2.000000        7.000000
# 8        3.000000        6.000000
# 9        4.000000        5.000000
# 10       5.000000        4.000000
# 11       6.000000        5.000000
# 12       7.000000        6.000000
# 13       8.000000        3.000000
# 14       5.548387        4.000000
# 15       5.000000        5.000000
# 16       6.000000        4.580645
# 17       7.000000        6.000000
# 18       8.000000        3.000000
# 19       4.000000        5.000000
# 20       3.000000        6.000000
# 21       2.000000        7.000000
# 22       5.000000        4.000000
# 24       7.000000        6.000000
# 25       8.000000        4.000000
# 31       7.000000        6.000000
# ...

# %%
y = Data[['Final_Score']]

# %%
y
# Out:
#     Final_Score
# 0     55.000000
# 1     60.000000
# 2     62.000000
# 3     70.000000
# 4     72.000000
# 5     75.000000
# 6     80.000000
# 7     50.000000
# 8     55.000000
# 9     65.000000
# 10    68.000000
# 11    72.000000
# 12    76.000000
# 13    85.000000
# 14    65.000000
# 15    70.000000
# 16    72.000000
# 17    75.000000
# 18    80.000000
# 19    60.000000
# 20    69.903226
# 21    52.000000
# 22    68.000000
# 24    75.000000
# 25    80.000000
# 31    76.000000
# 47    45.000000
# 48    88.000000
# 49    92.000000
# 50    40.000000
# 51    90.000000
# 52    94.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
plt.scatter(Data["Hours_Studied"],Data["Internet_Usage"] ,Data["Final_Score"])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from  sklearn.linear_model import LinearRegression

# %%
Li= LinearRegression()

# %%
Li.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
# array([[-1.85656665,  2.52308951],
#        [-0.26338835,  0.37618116],
#        [ 0.93149538, -0.16054593],
#        [ 0.5332008 ,  0.91290824],
#        [-1.0599775 ,  0.91290824],
#        [-0.66168292,  0.37618116],
#        [ 1.32978995, -1.23400011],
#        [ 0.5332008 ,  0.91290824],
#        [ 0.5332008 ,  0.91290824],
#        [-1.45827207, -0.69727302]])

# %%
Li.coef_
# Out:
# array([[11.15723469, -1.44197146]])

# %%
Li.intercept_
# Out:
# array([70.67741935])

# %%
y_pred = Li.predict(X_test)

# %%
y_pred
# Out:
# array([[46.32504648],
#        [67.19629125],
#        [81.30183454],
#        [75.31007821],
#        [57.53461401],
#        [62.7524252 ],
#        [87.29359088],
#        [75.31007821],
#        [75.31007821],
#        [55.41258339]])

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9641262953567047

# %% [markdown]
# ### 04 Model

# %%
X = Data[['Hours_Studied','Attendance']]

# %%
X
# Out:
#     Hours_Studied  Attendance
# 0        2.000000   75.000000
# 1        3.000000   80.000000
# 2        4.000000   78.000000
# 3        5.000000   85.000000
# 4        6.000000   88.000000
# 5        7.000000   90.000000
# 6        8.000000   92.000000
# 7        2.000000   70.000000
# 8        3.000000   75.000000
# 9        4.000000   82.000000
# 10       5.000000   85.000000
# 11       6.000000   88.000000
# 12       7.000000   90.000000
# 13       8.000000   95.000000
# 14       5.548387   80.000000
# 15       5.000000   85.000000
# 16       6.000000   88.000000
# 17       7.000000   90.000000
# 18       8.000000   92.000000
# 19       4.000000   84.774194
# 20       3.000000   78.000000
# 21       2.000000   70.000000
# 22       5.000000   85.000000
# 24       7.000000   90.000000
# 25       8.000000   92.000000
# 31       7.000000   90.000000
# 47       1.000000   65.000000
# 48       9.000000   96.000000
# 49      10.000000   98.000000
# 50       1.000000   60.000000
# ...

# %%
y = y = Data[['Final_Score']]

# %%
y
# Out:
#     Final_Score
# 0     55.000000
# 1     60.000000
# 2     62.000000
# 3     70.000000
# 4     72.000000
# 5     75.000000
# 6     80.000000
# 7     50.000000
# 8     55.000000
# 9     65.000000
# 10    68.000000
# 11    72.000000
# 12    76.000000
# 13    85.000000
# 14    65.000000
# 15    70.000000
# 16    72.000000
# 17    75.000000
# 18    80.000000
# 19    60.000000
# 20    69.903226
# 21    52.000000
# 22    68.000000
# 24    75.000000
# 25    80.000000
# 31    76.000000
# 47    45.000000
# 48    88.000000
# 49    92.000000
# 50    40.000000
# 51    90.000000
# 52    94.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
plt.scatter(Data["Attendance"],Data["Final_Score"])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from  sklearn.linear_model import LinearRegression

# %%
Li= LinearRegression()

# %%
Li.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
Li.coef_
# Out:
# array([[7.25796426, 5.12243034]])

# %%
Li.intercept_
# Out:
# array([70.67741935])

# %%
y_pred = Li.predict(X_test)

# %%
y_pred
# Out:
# array([[42.69603801],
#        [68.58925774],
#        [81.27407792],
#        [77.23687104],
#        [57.07564673],
#        [63.97885132],
#        [87.03088343],
#        [77.23687104],
#        [77.23687104],
#        [54.18483894]])

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9825858032719952

# %% [markdown]
# ## 05 Model

# %%
X = Data[['Hours_Studied','Internet_Usage','Sleep_Hours','Attendance']]

# %%
X
# Out:
#     Hours_Studied  Internet_Usage  Sleep_Hours  Attendance
# 0        2.000000        3.000000     6.000000   75.000000
# 1        3.000000        2.000000     7.000000   80.000000
# 2        4.000000        4.000000     6.000000   78.000000
# 3        5.000000        3.000000     8.000000   85.000000
# 4        6.000000        5.000000     7.000000   88.000000
# 5        7.000000        6.000000     6.000000   90.000000
# 6        8.000000        4.000000     7.000000   92.000000
# 7        2.000000        7.000000     5.000000   70.000000
# 8        3.000000        6.000000     6.000000   75.000000
# 9        4.000000        5.000000     7.000000   82.000000
# 10       5.000000        4.000000     8.000000   85.000000
# 11       6.000000        5.000000     6.000000   88.000000
# 12       7.000000        6.000000     7.000000   90.000000
# 13       8.000000        3.000000     8.000000   95.000000
# 14       5.548387        4.000000     7.000000   80.000000
# ...

# %%
 y = Data[['Final_Score']]

# %%
y
# Out:
#     Final_Score
# 0     55.000000
# 1     60.000000
# 2     62.000000
# 3     70.000000
# 4     72.000000
# 5     75.000000
# 6     80.000000
# 7     50.000000
# 8     55.000000
# 9     65.000000
# 10    68.000000
# 11    72.000000
# 12    76.000000
# 13    85.000000
# 14    65.000000
# 15    70.000000
# 16    72.000000
# 17    75.000000
# 18    80.000000
# 19    60.000000
# 20    69.903226
# 21    52.000000
# 22    68.000000
# 24    75.000000
# 25    80.000000
# 31    76.000000
# 47    45.000000
# 48    88.000000
# 49    92.000000
# 50    40.000000
# 51    90.000000
# 52    94.000000

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from  sklearn.linear_model import LinearRegression

# %%
Li= LinearRegression()

# %%
Li.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
Li.coef_
# Out:
# array([[ 7.14786268, -1.60905012, -0.97249542,  4.67887513]])

# %%
Li.intercept_
# Out:
# array([70.67741935])

# %%
y_pred = Li.predict(X_test)

# %%
y_pred
# Out:
# array([[42.61712367],
#        [68.04450617],
#        [80.84565942],
#        [75.22433141],
#        [56.90714434],
#        [63.35856141],
#        [86.18944687],
#        [75.22433141],
#        [75.22433141],
#        [56.65105177]])

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9813261045137422
